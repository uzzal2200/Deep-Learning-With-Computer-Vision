# %% [markdown]
# ### MatplotLib

# %%
# Matplotlib is usually pre-installed in Colab, but you can install it if needed
# !pip install matplotlib

# importing libraries
import matplotlib.pyplot as plt

# %%
image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'
image = plt.imread(image_path)

# %%
plt.imshow(image)

# %%
print(image)
# Out:
# [[[223 222 227]
#   [210 209 214]
#   [208 207 212]
#   ...
#   [216 216 218]
#   [217 217 219]
#   [223 223 225]]
#
#  [[226 225 230]
#   [213 212 217]
#   [209 208 213]
#   ...
#   [216 216 218]
#   [218 218 220]
#   [221 221 223]]
#
#  [[227 226 231]
#   [216 215 220]
#   [210 209 214]
#   ...
#   [221 221 223]
#   [223 223 225]
#   [222 222 224]]
#
#  ...
#
#  [[  0  16  10]
#   [  4  21  15]
#   [  5  22  16]
#   ...
#   [ 22  44  31]
#   [ 18  40  27]
#   [ 10  32  19]]
#
#  [[  0  13   7]
#   [  3  20  14]
#   [  5  22  16]
#   ...
#   [ 29  51  38]
#   [ 21  43  30]
#   [ 10  32  19]]
#
#  [[  8  25  19]
#   [ 15  32  26]
#   [ 14  31  25]
#   ...
#   [ 41  63  50]
#   [ 32  54  41]
#   [ 18  40  27]]]

# %%
print(image.shape)
# Out:
# (6000, 4000, 3)

# %% [markdown]
# ### OpenCV

# %%
# importing libraries
import cv2
from matplotlib import pyplot as plt # notice that we have imported pyplot differently

# %%
# Load an image
image_path = 'sample_data/orange-1.jpg'  # Use your image path
image = cv2.imread(image_path) # loading image using openCV

# Display the image
plt.imshow(image) # showing image uisng matplotlib
# plt.axis('off')  # Hide axes
# plt.show()

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
print(image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
image.shape
# Out:
# (563, 612, 3)

# %% [markdown]
# **Why the image looks different?**
#
# OpenCV uses BGR image format. So, when we read an image using cv2. imread() it interprets in BGR format by default.
#
# **OpenCV loads image in BGR and we are plotting RGB Image**
#
# **So we need to convert the BGR to RGB**

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converting BGR to RGB
plt.imshow(image_rgb)

# %% [markdown]
# ## ColorSpace conversion

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# Load an image
image_path = '/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/pexels-maxandrey-1366630.jpg'  # Upload your image to Colab
image = cv2.imread(image_path)

rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert BGR to Grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Convert BGR to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
# Display the images
plt.figure(figsize=(15, 5))

plt.subplot(1, 4, 1)
plt.imshow(image)
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 4, 2)
plt.imshow(rgb_image)
plt.axis('off')
plt.title('RGB Image')

plt.subplot(1, 4, 3)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')

plt.subplot(1, 4, 4)
plt.imshow(hsv_image)
plt.axis('off')
plt.title('HSV Image')

plt.show()

# %%
print(image.shape)
print(rgb_image.shape)
print(gray_image.shape)
# Out:
# (6000, 4000, 3)
# (6000, 4000, 3)
# (6000, 4000)

# %%
plt.imshow(gray_image, cmap='gray')
